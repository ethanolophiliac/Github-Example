# %% [markdown]
# # Introduction
#
# New York City is a booming metropolis with vibrant energy and endless diversity. This diversity allows its residents to develop some of the most pristine dishes that people have ever tasted. For this project, we will find the best location in New York City for Chinese Restaurants.

# %% [markdown]
# ## Data
#
# The date we will be using includes:
#
# 1) Latitude and Longitude of Boroughs and Neighborhoods in New York City
# 2) Chinese Restaurants in each of these
# 3) Geospace data
